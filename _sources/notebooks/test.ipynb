# %% [markdown]
# # FFT

# %%
import numpy as np

# %% [markdown]
# Eqatuin $f(x) = \int g(x) dx$

# %%
def f(x):
    return 0

# %% [markdown]
# ## Step 2

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 20)
plt.plot(x, np.sin(x))
